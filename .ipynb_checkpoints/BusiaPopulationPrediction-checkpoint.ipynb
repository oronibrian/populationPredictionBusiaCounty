# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn
from sklearn.preprocessing import MinMaxScaler 
from sklearn.svm import SVR

# %%
from matplotlib import rc
rc('lines', linewidth=0.5)
rc('font', family='sans-serif', size=12)
rc('axes', labelsize=12)
rc('xtick', labelsize=10)
rc('ytick', labelsize=10)

plt.style.use('ggplot')

# %%
population_data=pd.read_csv('Busia_Population_Pyramid_Data2009.csv')

# %%
df = pd.DataFrame(population_data)

# %% [markdown]
# # Set the index of the data set object id in the data (Cleaning the data set to the desired level)

# %%
df.set_index(['OBJECTID']).head()
# Out:
#           Age  Female   Male  Male_Inverse
# OBJECTID
# 0           0   13705  13568        -13568
# 1           1   12390  12320        -12320
# 2           2   13621  13654        -13654
# 3           3   13392  13291        -13291
# 4           4   12852  12980        -12980

# %% [markdown]
# ## Remove undesired data record

# %%
final_data=df.drop(['Male_Inverse'],axis=1)

# %%
#final_data.plot(x="Age", y=["Female", "Male"], kind="line",figsize=(12, 10))

final_data.set_index('Age')[["Female", "Male"]].plot.line(figsize=(12, 10),title='Population')
plt.xlabel('Age')
plt.ylabel('Population')
plt.savefig('images/BusiaPopulation.png')
plt.show()

# %% [markdown]
# ## Total male and female population in the county

# %%
maledata=df['Male']
femaledata=df['Female']
Age=df['Age']

# %%
total=final_data.sum(axis=0)

# %%
total.drop(['Age','OBJECTID'])
# Out:
# Female    387658
# Male      355934
# dtype: int64

# %%
total.drop(['Age','OBJECTID']).plot(kind='bar',figsize=(10, 8),title='Total Female vs Men')
plt.savefig('images/TotalBusiaPopulation.png')
plt.show()

# %% [markdown]
# ## Create vector of the data

# %%
#Convert data to an array and rescale to 0 nd 1

age=Age.values.reshape(-1, 1)
# mdata=maledata.values.reshape(-1, 1)

# %%
svr_lin=SVR(kernel='linear',C=1e3)
svr_poly=SVR(kernel='poly',C=1e3,degree=2)
svr_rbf=SVR(kernel='rbf',C=1e3,gamma=1.0)

# %%
svr_lin.fit(age,maledata)
svr_poly.fit(age,maledata)
svr_rbf.fit(age,maledata)
# Out:
# SVR(C=1000.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=1.0,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
plt.figure(figsize=(12, 10),dpi=80)
plt.scatter(age,maledata,color='black',label='Male Data')
plt.plot(age,svr_rbf.predict(age),color='red',label='RBF Model')
plt.plot(age,svr_lin.predict(age),color='green',label='Linear Model')
plt.plot(age,svr_poly.predict(age),color='blue',label='Polynomial Model')
plt.title('Support Vector Regression of Male Population(Busia county)')
plt.legend()
plt.savefig('images/Support_Vector_Regression_of_Male_Population.png')
plt.show()

# %%
print(svr_lin.predict(age)[0])
# Out:
# 9620.123255813936

# %%
print(svr_rbf.predict(age)[0])
# Out:
# 4120.756242631149

# %%
print(svr_poly.predict(age)[0])
# Out:
# 7841.399929779554
