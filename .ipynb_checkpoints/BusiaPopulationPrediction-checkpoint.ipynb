# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
from matplotlib import rc
rc('lines', linewidth=0.5)
rc('font', family='sans-serif', size=12)
rc('axes', labelsize=12)
rc('xtick', labelsize=10)
rc('ytick', labelsize=10)

plt.style.use('ggplot')

# %%
population_data=pd.read_csv('Busia_Population_Pyramid_Data2009.csv')

# %%
df = pd.DataFrame(population_data)

# %% [markdown]
# # Set the index of the data set object id in the data (Cleaning the data set to the desired level)

# %%
df.set_index(['OBJECTID']).head()
# Out:
#           Age  Female   Male  Male_Inverse
# OBJECTID
# 0           0   13705  13568        -13568
# 1           1   12390  12320        -12320
# 2           2   13621  13654        -13654
# 3           3   13392  13291        -13291
# 4           4   12852  12980        -12980

# %% [markdown]
# ## Remove undesired data record

# %%
final_data=df.drop(['Male_Inverse'],axis=1)

# %%
#final_data.plot(x="Age", y=["Female", "Male"], kind="line",figsize=(12, 10))

final_data.set_index('Age')[["Female", "Male"]].plot.line(figsize=(12, 10),title='Population')
plt.xlabel('Age')
plt.ylabel('Population')

plt.show()

# %% [markdown]
# ## Total male and female population in the county

# %%
total=final_data.sum(axis=0)

# %%
total.drop(['Age','OBJECTID'])
# Out:
# Female    387658
# Male      355934
# dtype: int64

# %%
total.drop(['Age','OBJECTID']).plot(kind='bar',figsize=(10, 8),title='Total Female vs Men')
plt.show()
